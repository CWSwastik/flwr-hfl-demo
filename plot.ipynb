# %%
import matplotlib.pyplot as plt

rounds = list(range(1, 11))
loss_values_hfl = [
    0.07028603553771973, 0.05382544919848442, 0.049233993515372276,
    0.0466227401047945, 0.04434414394199848, 0.043033311143517494,
    0.04167027026414871, 0.041625674813985825, 0.04003422521054745,
    0.039810532703995705
]

loss_values_2tier = [
    0.056152972082297005, 0.049313982327779136, 0.04620329663157463,
    0.044002206375201545, 0.042940342177947365, 0.04231380671262741,
    0.040663935244083405, 0.039747836689154305, 0.03958802794416746,
    0.03851930548747381
]

plt.figure(figsize=(8, 5))
plt.plot(rounds, loss_values_hfl, marker='o', linestyle='-', color='b', label='HFL Loss')
plt.plot(rounds, loss_values_2tier, marker='s', linestyle='-', color='r', label='2-Tier FL Loss')
plt.xlabel("Round")
plt.ylabel("Loss")
plt.title("Loss Reduction Over Rounds (HFL vs 2-Tier FL)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()
